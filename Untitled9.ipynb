# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# Sample dataset
data = {
    'study_hours': [1, 2, 3, 4, 5, 6, 7, 8],
    'attendance': [50, 60, 65, 70, 75, 80, 90, 95],
    'sleep_hours': [5, 6, 6, 7, 7, 8, 8, 9],
    'result': [0, 0, 0, 1, 1, 1, 1, 1]  # 0 = Fail, 1 = Pass
}

df = pd.DataFrame(data)

X = df[['study_hours', 'attendance', 'sleep_hours']]
y = df['result']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = LogisticRegression()
model.fit(X_train, y_train)

# Prediction
prediction = model.predict([[4, 70, 7]])
print("Prediction (0=Fail, 1=Pass):", prediction)
# Out:
# Prediction (0=Fail, 1=Pass): [1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# Dataset
data = {
    'study_hours': [1, 2, 3, 4, 5, 6, 7, 8],
    'attendance': [50, 60, 65, 70, 75, 80, 90, 95],
    'sleep_hours': [5, 6, 6, 7, 7, 8, 8, 9],
    'result': [0, 0, 0, 1, 1, 1, 1, 1]
}

df = pd.DataFrame(data)

# Inputs and output
X = df[['study_hours', 'attendance', 'sleep_hours']]
y = df['result']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train model
model = LogisticRegression()
model.fit(X_train, y_train)

# Prediction
new_data = pd.DataFrame([[4, 70, 7]], columns=['study_hours', 'attendance', 'sleep_hours'])
prediction = model.predict(new_data)

print("Prediction (0=Fail, 1=Pass):", prediction)
# Out:
# Prediction (0=Fail, 1=Pass): [1]
